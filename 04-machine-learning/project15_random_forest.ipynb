# %% [markdown]
# # Project 15_Random Forest (ENSEMBLE MODEL)

# %% [markdown]
# ###  Step: 1 — Load the data

# %%
# import library
import pandas as pd

# Load the data
df = pd.read_csv("final_data.csv")
print(df)
# Out:
#      Name  Age  Salary Salary_Category Age_Group       Profile
# 0     Ali   25   50000             Low       Mid       Mid_Low
# 1    Sara   27   60000          Medium       Mid    Mid_Medium
# 2    John   22   58400          Medium     Young  Young_Medium
# 3  Ayesha   28   52000             Low       Mid       Mid_Low
# 4   David   35   80000            High    Senior   Senior_High

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd

# Features & target
X = df[["Age", "Salary"]]
y = df["Salary_Category"]

# Model
rf = RandomForestClassifier(random_state=42)

# Train
rf.fit(X, y)

# Predict
prediction = rf.predict(
    pd.DataFrame([[30, 60000]], columns=["Age", "Salary"])
)

print("Random Forest Prediction:", prediction[0])
# Out:
# Random Forest Prediction: Medium

# %%
import pandas as pd

importance = rf.feature_importances_

feature_names = ["Age", "Salary"]

for name, imp in zip(feature_names, importance):
    print(name, ":", imp)
# Out:
# Age : 0.43027777777777765
# Salary : 0.5697222222222224

# %%
# save the data
df.to_csv("final_data.csv", index=False)
