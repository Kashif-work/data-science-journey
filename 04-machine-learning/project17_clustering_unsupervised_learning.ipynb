# %% [markdown]
# # Project 17_Clustering (UNSUPERVISED LEARNING)

# %%
# import library
import pandas as pd

# Load the data
df = pd.read_csv("final_data.csv")
print(df)
# Out:
#      Name  Age  Salary Salary_Category Age_Group       Profile  Cluster
# 0     Ali   25   50000             Low       Mid       Mid_Low        0
# 1    Sara   27   60000          Medium       Mid    Mid_Medium        0
# 2    John   22   58400          Medium     Young  Young_Medium        0
# 3  Ayesha   28   52000             Low       Mid       Mid_Low        0
# 4   David   35   80000            High    Senior   Senior_High        1

# %%
from sklearn.cluster import KMeans

# Features
X = df[["Age", "Salary"]]

# Model
kmeans = KMeans(n_clusters=2, random_state=42)

# Fit
kmeans.fit(X)

# Assign clusters
df["Cluster"] = kmeans.labels_

print(df)
# Out:
#      Name  Age  Salary Salary_Category Age_Group       Profile  Cluster
# 0     Ali   25   50000             Low       Mid       Mid_Low        0
# 1    Sara   27   60000          Medium       Mid    Mid_Medium        0
# 2    John   22   58400          Medium     Young  Young_Medium        0
# 3  Ayesha   28   52000             Low       Mid       Mid_Low        0
# 4   David   35   80000            High    Senior   Senior_High        1

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

inertia = []

k_range = range(1, 6)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df[["Age", "Salary"]])
    inertia.append(kmeans.inertia_)

plt.plot(k_range, inertia, marker='o')
plt.title("Elbow Method")
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Inertia")
plt.show()

# %%
# save data
df.to_csv("final_data.csv", index=False)
