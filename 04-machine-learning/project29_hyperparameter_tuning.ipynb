# %% [markdown]
# # Project 29 — Hyperparameter Tuning

# %% [markdown]
# ## Step 1 — GridSearchCV

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# Dataset
data = {
    "Age": [22, 25, 47, 52, 46, 56, 27, 30, 40, 35],
    "Salary": [15000, 29000, 48000, 60000, 52000, 75000, 32000, 58000, 62000, 45000],
    "Purchased": [0, 0, 1, 1, 1, 1, 0, 1, 1, 0]
}

df_tree = pd.DataFrame(data)

# Features & Target
X = df_tree[["Age", "Salary"]]
y = df_tree["Purchased"]

# Model
rf = RandomForestClassifier(random_state=42)

# Parameter grid
params = {
    "n_estimators": [10, 50, 100],
    "max_depth": [1, 2, 3, None]
}

# Grid Search
grid = GridSearchCV(
    rf,
    params,
    cv=3
)

grid.fit(X, y)

print("Best Parameters:", grid.best_params_)
print("Best Score:", grid.best_score_)
# Out:
# Best Parameters: {'max_depth': 1, 'n_estimators': 10}
# Best Score: 0.8888888888888888

# %%
best_model = grid.best_estimator_

pred = best_model.predict(
    pd.DataFrame([[30, 58000]], columns=["Age", "Salary"])
)

print("Optimized Model Prediction:", pred[0])
# Out:
# Optimized Model Prediction: 1
