# %% [markdown]
# # Project 8_Data Visualization (Advanced)

# %%
# import library
import pandas as pd
import matplotlib.pyplot as plt
# Load the data
df = pd.read_csv("employee_salary_dataset.csv")
print(df)
# Out:
#      Name  Age  Salary Salary_Category Age_Group       Profile
# 0     Ali   25   50000             Low       Mid       Mid_Low
# 1    Sara   27   60000          Medium       Mid    Mid_Medium
# 2    John   22   58400          Medium     Young  Young_Medium
# 3  Ayesha   28   52000             Low       Mid       Mid_Low
# 4   David   35   80000            High    Senior   Senior_High

# %%
plt.scatter(df["Age"], df["Salary"])
plt.title("Age vs Salary")
plt.xlabel("Age")
plt.ylabel("Salary")

plt.show()

# %%
import numpy as np

# Scatter plot
plt.scatter(df["Age"], df["Salary"])

# Trend line
z = np.polyfit(df["Age"], df["Salary"], 1)
p = np.poly1d(z)

plt.plot(df["Age"], p(df["Age"]))

plt.title("Age vs Salary with Trend Line")
plt.xlabel("Age")
plt.ylabel("Salary")

plt.show()

# %%
# Step 3: Salary Category Count

df["Salary_Category"].value_counts().plot(kind="bar")

plt.title("Count of Salary Categories")
plt.xlabel("Category")
plt.ylabel("Count")

plt.show()

# %%
# save data
df.to_csv("employee_salary_dataset.csv", index=False)
