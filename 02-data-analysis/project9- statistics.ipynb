# %% [markdown]
# # Project 9 - Statistics

# %%
# import library
import pandas as pd

# Load the data
df = pd.read_csv("employee_salary_dataset.csv")
print(df)
# Out:
#      Name  Age  Salary Salary_Category Age_Group       Profile
# 0     Ali   25   50000             Low       Mid       Mid_Low
# 1    Sara   27   60000          Medium       Mid    Mid_Medium
# 2    John   22   58400          Medium     Young  Young_Medium
# 3  Ayesha   28   52000             Low       Mid       Mid_Low
# 4   David   35   80000            High    Senior   Senior_High

# %%
# Variance and Standard Deviation
variance = df["Salary"].var()
std_dev = df["Salary"].std()

print("Variance:", variance)
print("Standard Deviation:", std_dev)
# Out:
# Variance: 141632000.0
# Standard Deviation: 11900.92433384903

# %%
# Step 2: Mean vs Median

mean_salary = df["Salary"].mean()
median_salary = df["Salary"].median()

print("Mean Salary:", mean_salary)
print("Median Salary:", median_salary)
# Out:
# Mean Salary: 60080.0
# Median Salary: 58400.0

# %%
# Step 3: Correlation

correlation = df["Age"].corr(df["Salary"])

print("Correlation between Age and Salary:", correlation)
# Out:
# Correlation between Age and Salary: 0.7826501054489625

# %%
# save data
df.to_csv("employee_salary_dataset.csv", index=False)
